# %% [markdown]
# # 作業1
#
# 我在Kaggle選的Dataset
# Suicide Rates Overview 1985 to 2016
# https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016
# 1. 這是調查全球大部分國家，在1985-2016的自殺率，與一些其它數據，的統計資料。這是個很嚴肅的議題，如果能因為分析的結果有效的降低部分國家的自殺率，那是一大功德
# 2. 目前資料就是來自於kaggle上方連結，有一個csv檔案
# 3. 資料型態為csv, 純文字檔
# 4. 目前這資料有的欄位有，國家、年度、性別、年齡區間、自殺案例數、該區間條件總人口數、每十萬人自殺案例數、該國該年度發展指數(HDI)、年度GDP、人均GDP、世代等數據。可以看需求來產出各類統計圖表，分析趨勢，進行比較

# %% [markdown]
# # 作業2
# 經營一個自由載客車隊
# 1. 如何提升業績？假設規模遍佈全省，所以可以有不少統計資料，地點、時間、熟客返回次數、距離、車資等必定會有的資料。另外還可能有一些補充資料，例如特殊需求、同車人數、等待時間、預約卻未搭乘狀況、意外狀況等等。
# 2. 資料從何而來？不太清楚ㄟ，可能只能上網找。用猜的
# 3. 蒐集來的資料，一般都會是純文字的型態
# 4. 假設的驗證，把找到的資料，跟車資做交叉比對，尋找那些因素的正向或負向，與累計營收有相關性

# %% [markdown]
# # 作業3

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)*(y - yp)) / len(y)
    return mse

#MSE = mean_squared_error(y, y_hat)
#print("The Mean squared error is %.3f" % (MSE))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

#MAE = mean_absolute_error(y, y_hat)
#print("The Mean absolute error is %.3f" % (MAE))

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 206.688
# The Mean absolute error is 12.001
